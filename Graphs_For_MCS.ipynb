# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
totalcompleteppo = [93.6,93.4,92.3,77.2,76.9,75.3,69.2,68.9,66.9]

totalcompletedqn = [97.9,97.8,97.1,94.0,93.6,92.1,89.6,88.6,86.5]

totalcompletears = [96.09,95.08,94.40,81.12,80.36,78.44,74.64,73.40,69.84]
    
totalcompleteapxnon = [98.08,97.92,97.24,95.68,95.40,93.96,93.88,93.28,90.92]

# totalcompleteapxpre = [98.56,98.44,97.88,96.48,96.12,94.88,94.92,94.16,91.72]

# %%
plt.clf()
plt.figure(figsize=(14,8))
try:
    plt.plot(range(0,len(totalcompleteapxnon)),totalcompleteapxnon,'-b',markersize=1,label="Ape-X")
    # plt.plot(range(0,len(totalcompleteapxpre)),totalcompleteapxpre,'-co',markersize=1,label="Ape-X Pre")
    plt.plot(range(0,len(totalcompletears)),totalcompletears,':mo',markersize=1,label="ARS")
    plt.plot(range(0,len(totalcompletedqn)),totalcompletedqn,'-.go',markersize=1,label="DQN")
    plt.plot(range(0,len(totalcompleteppo)),totalcompleteppo,'--r',markersize=1,label="PPO")
except ValueError:
    pass

plt.ylabel("Total Completion Percentage")
plt.xlabel("Dataset")
plt.title("Percentage of Completing All Jobs")
plt.legend(loc="lower right")
plt.savefig("completionallalgonopre.png")
plt.show()

# %%
# DEGRADATION NON PREEMPTION
degx = [0.2,0.4,0.6,0.8,1]
hicompletion = [96.90,96.63,96.37,95.93,95.51]
locompletion = [95.38,94.96,94.65,94.10,93.79]
# Total Load
loadx = [0.3,0.6,0.9]
hicompletion2 = [98.64,96.47,93.69]
locompletion2 = [97.37,94.18,92.16]
# LO Percentage
lox = [0.3,0.5,0.8]
hicompletion3 = [96.02,96.35,96.44]
locompletion3 = [95.45,94.75,93.51]
# Per Dataset
dataset = [1,2,3,4,5,6,7,8,9]
hicompletion4 = [98.05,98.56,99.32,95.86,96.23,97.32,94.14,94.26,92.68]
locompletion4 = [98.01,97.29,96.79,94.97,94.41,93.16,93.37,92.55,90.57]

# %%
plt.clf()
try:
    plt.plot(degx,hicompletion,'--r',markersize=1,label="HI")
    plt.plot(degx,locompletion,'-b',markersize=1,label="LO")
except ValueError:
    pass

plt.ylabel("Completion Percentage")
plt.xlabel("Degredation Chance")
plt.ylim([90,100])
# plt.title("Percentage of HI vs LO completion percentage against degradation chance")
plt.legend(loc="lower right")
plt.savefig("noncompletionhivslowdegrade.png")
plt.show()

# %%
plt.clf()
try:
    plt.plot(loadx,hicompletion2,'--r',markersize=1,label="HI")
    plt.plot(loadx,locompletion2,'-b',markersize=1,label="LO")
except ValueError:
    pass

plt.ylabel("Completion Percentage")
plt.xlabel("Total Load")
plt.ylim([90,100])
# plt.title("Percentage of HI vs LO completion percentage against Total Load")
plt.legend(loc="lower right")
plt.savefig("noncompletionhivslowload.png")
plt.show()

# %%
plt.clf()
try:
    plt.plot(lox,hicompletion3,'--r',markersize=1,label="HI")
    plt.plot(lox,locompletion3,'-b',markersize=1,label="LO")
except ValueError:
    pass

plt.ylabel("Completion Percentage")
plt.xlabel("LO Percentage")
plt.ylim([90,100])
# plt.title("Percentage of HI vs LO completion percentage against LO Percentage")
plt.legend(loc="lower right")
plt.savefig("noncompletionhivslowlo.png")
plt.show()

# %%
plt.clf()
try:
    plt.plot(dataset,hicompletion4,'--r',markersize=1,label="HI")
    plt.plot(dataset,locompletion4,'-b',markersize=1,label="LO")
except ValueError:
    pass

plt.ylabel("Completion Percentage")
plt.xlabel("Dataset")
plt.ylim([90,100])
# plt.title("Average Percentage of HI vs LO completion percentage for each dataset")
plt.legend(loc="lower right")
plt.savefig("noncompletionhivslowdataset.png")
plt.show()

# %%
# DEGRADATION PREEMPTION
degx = [0.2,0.4,0.6,0.8,1]
hicompletionpre = [97.70,97.40,97.10,96.56,96.30]
locompletionpre = [96.28,95.84,95.42,94.91,94.54]
# Total Load
loadx = [0.3,0.6,0.9]
hicompletion2pre = [99.07,97.30,94.67]
locompletion2pre = [98.03,95.15,92.99]
# LO Percentage
lox = [0.3,0.5,0.8]
hicompletion3pre = [96.80,96.94,97.30]
locompletion3pre = [96.24,95.56,94.37]
# Per Dataset
dataset = [1,2,3,4,5,6,7,8,9]
hicompletion4pre = [98.54,98.97,99.71,96.70,96.90,98.29,95.17,94.94,93.90]
locompletion4pre = [98.48,98.05,97.56,96.05,95.25,94.16,94.20,93.38,91.39]

# %%
plt.clf()
try:
    plt.plot(degx,hicompletionpre,'--r',markersize=1,label="HI")
    plt.plot(degx,locompletionpre,'-b',markersize=1,label="LO")
except ValueError:
    pass

plt.ylabel("Completion Percentage")
plt.xlabel("Degredation Chance")
plt.ylim([90,100])
# plt.title("Percentage of HI vs LO completion percentage against degradation chance")
plt.legend(loc="lower right")
plt.savefig("precompletionhivslowdegrade.png")
plt.show()

# %%
plt.clf()
try:
    plt.plot(loadx,hicompletion2pre,'--r',markersize=1,label="HI")
    plt.plot(loadx,locompletion2pre,'-b',markersize=1,label="LO")
except ValueError:
    pass

plt.ylabel("Completion Percentage")
plt.xlabel("Total Load")
plt.ylim([90,100])
# plt.title("Percentage of HI vs LO completion percentage against Total Load")
plt.legend(loc="lower right")
plt.savefig("precompletionhivslowload.png")
plt.show()

# %%
plt.clf()
try:
    plt.plot(lox,hicompletion3pre,'--r',markersize=1,label="HI")
    plt.plot(lox,locompletion3pre,'-b',markersize=1,label="LO")
except ValueError:
    pass

plt.ylabel("Completion Percentage")
plt.xlabel("LO Percentage")
plt.ylim([90,100])
# plt.title("Percentage of HI vs LO completion percentage against LO Percentage")
plt.legend(loc="lower right")
plt.savefig("precompletionhivslowlo.png")
plt.show()

# %%
plt.clf()
try:
    plt.plot(dataset,hicompletion4pre,'--r',markersize=1,label="HI")
    plt.plot(dataset,locompletion4pre,'-b',markersize=1,label="LO")
except ValueError:
    pass

plt.ylabel("Completion Percentage")
plt.xlabel("Dataset")
plt.ylim([90,100])
# plt.title("Average Percentage of HI vs LO completion percentage for each dataset")
plt.legend(loc="lower right")
plt.savefig("precompletionhivslowdataset.png")
plt.show()

# %% [markdown]
# **COMPARISON BETWEEN PRE VS NON**

# %%
plt.clf()
try:
    plt.plot(degx,hicompletion,'--r',markersize=1,label="NonHI")
    plt.plot(degx,locompletion,'-b',markersize=1,label="NonLO")
    plt.plot(degx,hicompletionpre,'--g',markersize=1,label="PreHI")
    plt.plot(degx,locompletionpre,'-c',markersize=1,label="PreLO")
except ValueError:
    pass

plt.ylabel("Completion Percentage")
plt.xlabel("Degredation Chance")
plt.ylim([90,100])
plt.title("Percentage of HI vs LO completion percentage against degradation chance")
plt.legend(loc="lower right")
plt.savefig("prevsnoncompletionhivslowdegrade.png")
plt.show()

# %%
plt.clf()
try:
    plt.plot(loadx,hicompletion2,'--r',markersize=1,label="NonHI")
    plt.plot(loadx,locompletion2,'-b',markersize=1,label="NonLO")
    plt.plot(loadx,hicompletion2pre,'--g',markersize=1,label="PreHI")
    plt.plot(loadx,locompletion2pre,'-c',markersize=1,label="PreLO")
except ValueError:
    pass

plt.ylabel("Completion Percentage")
plt.xlabel("Total Load")
plt.ylim([90,100])
plt.title("Percentage of HI vs LO completion percentage against Total Load")
plt.legend(loc="lower right")
plt.savefig("prevsnoncompletionhivslowload.png")
plt.show()

# %%
plt.clf()
try:
    plt.plot(lox,hicompletion3,'--r',markersize=1,label="NonHI")
    plt.plot(lox,locompletion3,'-b',markersize=1,label="NonLO")
    plt.plot(lox,hicompletion3pre,'--g',markersize=1,label="PreHI")
    plt.plot(lox,locompletion3pre,'-c',markersize=1,label="PreLO")
except ValueError:
    pass

plt.ylabel("Completion Percentage")
plt.xlabel("LO Percentage")
plt.ylim([90,100])
plt.title("Percentage of HI vs LO completion percentage against LO Percentage")
plt.legend(loc="lower right")
plt.savefig("prevsnoncompletionhivslowlo.png")
plt.show()

# %%
plt.clf()
try:
    plt.plot(dataset,hicompletion4,'--r',markersize=1,label="NonHI")
    plt.plot(dataset,locompletion4,'-b',markersize=1,label="NonLO")
    plt.plot(dataset,hicompletion4pre,'--g',markersize=1,label="PreHI")
    plt.plot(dataset,locompletion4pre,'-c',markersize=1,label="PreLO")
except ValueError:
    pass

plt.ylabel("Completion Percentage")
plt.xlabel("Dataset")
plt.ylim([90,100])
plt.title("Percentage of HI vs LO completion percentage per Dataset")
plt.legend(loc="lower right")
plt.savefig("prevsnoncompletionhivslowdataset.png")
plt.show()

# %% [markdown]
# SPEEEEEED

# %%
DQNSPEED = [0.125,0.128,0.123,0.064,0.062,0.055,0.049,0.048,0.047]
ARSSPEED = [0.081,0.084,0.079,0.0396,0.0403,0.037,0.028,0.027,0.027]
PPOSPEED = [0.1175,0.12,0.1109,0.060,0.0615,0.055,0.046,0.045,0.045]
APEXPRESPEED = [0.1277,0.1283,0.118,0.063,0.068,0.059,0.0512,0.0504,0.0501]
APEXNONSPEED = [0.123,0.127,0.118,0.065,0.067,0.0593,0.0514,0.0502,0.0507]

# %%
plt.clf()
plt.figure(figsize=(14,8))
try:
  
    # plt.plot(range(0,len(APEXNONSPEED)),APEXNONSPEED,'-co',markersize=1,label="Ape-X Pre")
    plt.plot(range(0,len(APEXPRESPEED)),APEXPRESPEED,'-b',markersize=1,label="Ape-X")
    plt.plot(range(0,len(ARSSPEED)),ARSSPEED,':mo',markersize=1,label="ARS")
    plt.plot(range(0,len(DQNSPEED)),DQNSPEED,'-.go',markersize=1,label="DQN")
    plt.plot(range(0,len(PPOSPEED)),PPOSPEED,'--r',markersize=1,label="PPO")
except ValueError:
    pass

plt.ylabel("Per Run Execution Time")
plt.xlabel("Dataset")
plt.title("Percentage of Completing All Jobs")
plt.legend(loc="lower right")
plt.savefig("completionspeedtraining.png")
plt.show()
